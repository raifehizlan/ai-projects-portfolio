# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !gdown --folder https://drive.google.com/drive/folders/1gHUPY6YnpHuziQszJ1GD2W5MbTMdEOIG?usp=sharing
# Out:
# Processing file 1gX7l9kcR1UHucKgLy3QNRFWz_jLeqasT config.json
# Processing file 1gTR00HAP17rQvKyB9A_neU9ZqAe_v6we eval_results.txt
# Processing file 1gfddavPnkHerZT3K7dC2FSkbBAkz_3rf pytorch_model.bin
# Processing file 1gxB-yE_PZh9cSHktlDC9qOGzmAOmJLTQ special_tokens_map.json
# Processing file 1h-7a7XI0TmABAYGU-IXhuwFaOI_1_AR2 tokenizer_config.json
# Processing file 1gwRAqcSJTExDRN8lojt1aCI9owh4dYcm tokenizer.json
# Processing file 1gyH7lpZQRzlpyuT-QZqoUTqEAdccl--g training_args.bin
# Processing file 1h9Lzp3-A0DnDYfCSjfpDTS6A68uGj_b4 vocab.txt
# Retrieving folder contents
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1gX7l9kcR1UHucKgLy3QNRFWz_jLeqasT
# To: c:\Users\hizla\Documents\00_Fulstack\Projects\projects-portfolio\ml_models\model_cls\nlp-health-classifier-ade-base-en\config.json
#
#   0%|          | 0.00/826 [00:00<?, ?B/s]
# ...
