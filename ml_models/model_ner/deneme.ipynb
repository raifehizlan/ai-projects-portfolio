# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
https://drive.google.com/drive/folders/11fufo9GAvemGTkvomm4x_Nhh-QhQhezC?usp=drive_link

# %%
# !gdown --folder https://drive.google.com/drive/folders/11fufo9GAvemGTkvomm4x_Nhh-QhQhezC?usp=drive_link
# Out:
# Retrieving folder 1JrQVIEugUiiI1JAoS5KzU2V7_nRkNNen .ipynb_checkpoints
# Processing file 1274dzbClTbtOxXs_RI-GxCNONpmwVmx8 added_tokens.json
# Processing file 126oA9gkvN0GWxS9E3OvDUmoaloWO9tBd config.json
# Processing file 123BhI4Zh1AhwRlci2pDV5i53MKpAEWBN model_args.json
# Processing file 129zv6hNe8BxxCVYBq_0mMqVi3xwIRvSJ pytorch_model.bin
# Processing file 12BXHCN5_SkpGeJerTHrrtUJnVBJiuflU special_tokens_map.json
# Processing file 12EHotlGUKQKirmMyfLhwgXTRWjkHvxGo spm.model
# Processing file 12ODma-hZ26m2dayIBI3wpD0TpRWwY_ey tokenizer_config.json
# Processing file 12Iwp-ccXIuH786rWQMkGDIZ7j275D-4x training_args.bin
# Retrieving folder contents
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1274dzbClTbtOxXs_RI-GxCNONpmwVmx8
# To: c:\Users\hizla\Documents\00_Fulstack\Projects\projects-portfolio\ml_models\model_ner\nlp-health-ner-posology-base-en\added_tokens.json
#
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\hizla/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True
